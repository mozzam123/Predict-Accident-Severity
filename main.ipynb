# %%
import pandas as pd
import dask.dataframe as dd

# %%
df = dd.read_csv("US_Accidents_March23.csv")
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df.compute()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.compute()
#
# File ~/miniconda3/envs/datascience/lib/python3.11/site-packages/dask_expr/_collection.py:480, in FrameBase.compute(self, fuse, concatenate, **kwargs)
#     478     out = out.repartition(npartitions=1)
#     479 out = out.optimize(fuse=fuse)
# --> 480 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~/miniconda3/envs/datascience/lib/python3.11/site-packages/dask/base.py:372, in DaskMethodsMixin.compute(self, **kwargs)
#     348 def compute(self, **kwargs):
#     349     """Compute this dask collection
#     350
#     351     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     370     dask.compute
#     371     """
# --> 372     (result,) = compute(self, traverse=False, **kwargs)
#     373     return result
#
# ...
